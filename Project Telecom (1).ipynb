# %%
import pandas as pd

# %%
churn_analysis = pd.read_csv(r"C:\Users\amanb\Downloads\Telecom+Customer+Churn\telecom_customer_churn.csv")

# %%
churn_analysis.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
churn_analysis.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
churn_analysis["Offer"]= churn_analysis["Offer"].fillna(0)

# %%
churn_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        7043 non-null   object
#  1   gender                             7043 non-null   object
#  2   age                                7043 non-null   int64
#  3   married                            7043 non-null   object
#  4   number_of_dependents               7043 non-null   int64
#  5   city                               7043 non-null   object
#  6   zip_code                           7043 non-null   int64
#  7   latitude                           7043 non-null   float64
#  8   longitude                          7043 non-null   float64
#  9   number_of_referrals                7043 non-null   int64
#  10  tenure_in_months                   7043 non-null   int64
# ...

# %%
churn_analysis.describe()
# Out:
#                age  number_of_dependents      zip_code     latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          longitude  number_of_referrals  tenure_in_months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %%
churn_analysis.shape
# Out:
# (7043, 40)

# %%
churn_analysis.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
churn_analysis["Avg Monthly Long Distance Charges"]= churn_analysis["Avg Monthly Long Distance Charges"].fillna(0)

# %%
churn_analysis["Multiple Lines  "]= churn_analysis["Multiple Lines"].fillna(0)

# %%
churn_analysis["Internet Type"]= churn_analysis["Internet Type"].fillna(0)

# %%
churn_analysis["Avg Monthly GB Download"]= churn_analysis["Avg Monthly GB Download"].fillna(0)

# %%
churn_analysis["Online Security "]= churn_analysis["Online Security"].fillna(0)

# %%
churn_analysis["Online Backup"]= churn_analysis["Online Backup"].fillna(0)

# %%
churn_analysis["Device Protection Plan"]= churn_analysis["Device Protection Plan"].fillna(0)

# %%
churn_analysis["Premium Tech Support"]= churn_analysis["Premium Tech Support"].fillna(0)

# %%
churn_analysis["Streaming TV"]= churn_analysis["Streaming TV"].fillna(0)

# %%
churn_analysis["Streaming Movies"]= churn_analysis["Streaming Movies"].fillna(0)

# %%
churn_analysis["Streaming Music"]= churn_analysis["Streaming Music"].fillna(0)

# %%
churn_analysis["Unlimited Data"]= churn_analysis["Unlimited Data"].fillna(0)

# %%
churn_analysis["Churn Category"]= churn_analysis["Churn Category"].fillna(0)

# %%
churn_analysis["Churn Reason"]= churn_analysis["Churn Reason"].fillna(0)

# %%
churn_analysis.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                           0
# Avg Monthly GB Download                 0
# Online Security                      1526
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# ...

# %%
churn_analysis["Multiple Lines"]= churn_analysis["Multiple Lines"].fillna(0)

# %%
churn_analysis["Online Security"]= churn_analysis["Online Security"].fillna(0)

# %%
churn_analysis.isnull().sum()
# Out:
# Customer ID                          0
# Gender                               0
# Age                                  0
# Married                              0
# Number of Dependents                 0
# City                                 0
# Zip Code                             0
# Latitude                             0
# Longitude                            0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# Internet Type                        0
# Avg Monthly GB Download              0
# Online Security                      0
# Online Backup                        0
# Device Protection Plan               0
# Premium Tech Support                 0
# Streaming TV                         0
# Streaming Movies                     0
# ...

# %%
churn_analysis.columns = churn_analysis.columns.str.replace(" ","_")
churn_analysis.columns = churn_analysis.columns.str.lower()

# %%
churn_analysis.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'married', 'number_of_dependents',
#        'city', 'zip_code', 'latitude', 'longitude', 'number_of_referrals',
#        'tenure_in_months', 'offer', 'phone_service',
#        'avg_monthly_long_distance_charges', 'multiple_lines',
#        'internet_service', 'internet_type', 'avg_monthly_gb_download',
#        'online_security', 'online_backup', 'device_protection_plan',
#        'premium_tech_support', 'streaming_tv', 'streaming_movies',
#        'streaming_music', 'unlimited_data', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charge', 'total_charges', 'total_refunds',
#        'total_extra_data_charges', 'total_long_distance_charges',
#        'total_revenue', 'customer_status', 'churn_category', 'churn_reason',
#        'multiple_lines__', 'online_security_'],
#       dtype='object')

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:aman123@localhost:3306/Churn_analysis")

churn_analysis.to_sql(
    name="telecom_data",
    con=engine,
    if_exists="replace",   
    index=False
)
# Out:
# 7043

# %%
churn_analysis.to_csv("telecom_data.csv",
index = False, encoding = "utf-8-sig")
